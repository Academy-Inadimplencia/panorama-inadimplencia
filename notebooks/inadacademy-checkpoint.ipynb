# %%
import pandas as pd

# %%
jan14 = pd.read_csv('../data/bronze/planilha_2014/planilha_201401.csv', sep=";")

# %%
display(jan14)
# Out:
#        data_base  uf           tcb  sr cliente  \
# 0     2014-01-31  AC      Bancário NaN      PF
# 1     2014-01-31  AC      Bancário NaN      PF
# 2     2014-01-31  AC      Bancário NaN      PF
# 3     2014-01-31  AC      Bancário NaN      PF
# 4     2014-01-31  AC      Bancário NaN      PF
# ...          ...  ..           ...  ..     ...
# 3291  2014-01-31  AC  Cooperativas NaN      PF
# 3292  2014-01-31  AC  Cooperativas NaN      PF
# 3293  2014-01-31  AC  Cooperativas NaN      PF
# 3294  2014-01-31  AC  Cooperativas NaN      PF
# 3295  2014-01-31  AC  Cooperativas NaN      PF
#
#                                              ocupacao cnae_secao  \
# 0                         PF - Aposentado/pensionista          -
# 1                         PF - Aposentado/pensionista          -
# 2                         PF - Aposentado/pensionista          -
# 3                         PF - Aposentado/pensionista          -
# 4                         PF - Aposentado/pensionista          -
# ...
